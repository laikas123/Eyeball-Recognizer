# %%
#import cell
# %matplotlib notebook
import simpleaudio as sa
from scipy.io import wavfile as wav
from scipy import signal as sig
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import decimal
from scipy import signal
from skimage import color

# %%
base_path = "./69000/"


# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("background_poster.jpg")
x = [0, 50]
y = [100, 100]
plt.plot(x, y, color="white", linewidth=3)
imgplot = plt.imshow(img)
plt.show()

#returns y, x, #channels dimensions
print(np.shape(img)[0])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 527

# %%
base_path = "./69000/"


#origin of image is 0, 0 in the top left...
#keep that in mind
def draw_square_on_image(square_top_left_x, square_top_left_y, side_length, image_name):

    
    img = mpimg.imread(base_path + image_name + ".png")
    
    x_dimens = np.shape(img)[1]
    
    y_dimens = np.shape(img)[0]
    
    if(square_top_left_x + side_length >= x_dimens or square_top_left_x < 0 or square_top_left_x >= x_dimens):
        print("ERROR OUT OF X BOUNDS")
        return
    if(square_top_left_y + side_length >= y_dimens or square_top_left_y < 0 or square_top_left_y >= y_dimens):
        print("ERROR OUT OF Y BOUNDS")
        return
    
    
    #draw the top line
    x = [square_top_left_x, square_top_left_x+side_length]
    y = [square_top_left_y, square_top_left_y]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    #draw the left line
    x = [square_top_left_x, square_top_left_x]
    y = [square_top_left_y, square_top_left_y + side_length]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    #draw the right line
    x = [square_top_left_x+side_length, square_top_left_x+side_length]
    y = [square_top_left_y, square_top_left_y + side_length]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    #draw the bottom line
    x = [square_top_left_x, square_top_left_x+side_length]
    y = [square_top_left_y+side_length, square_top_left_y+side_length]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    
    imgplot = plt.imshow(img)
    plt.show()
    
    
    
draw_square_on_image(70, 50, 20, "69000")

# %%
base_path = "./69000/"

from time import sleep
from IPython.display import clear_output


#origin of image is 0, 0 in the top left...
#keep that in mind
def crop_square_of_image(square_top_left_x, square_top_left_y, side_length, image_name):

    
    img =  color.rgb2gray(mpimg.imread(base_path + image_name + ".png"))
    
    x_dimens = np.shape(img)[1]
    
    y_dimens = np.shape(img)[0]
    
    if(square_top_left_x + side_length >= x_dimens or square_top_left_x < 0 or square_top_left_x >= x_dimens):
        print("ERROR OUT OF X BOUNDS")
        return
    if(square_top_left_y + side_length >= y_dimens or square_top_left_y < 0 or square_top_left_y >= y_dimens):
        print("ERROR OUT OF Y BOUNDS")
        return
    
    
    image_cropped = img[square_top_left_y:square_top_left_y+side_length, square_top_left_x:square_top_left_x+side_length]
     
    #without heatmeap
#     plt.imshow(image_cropped, interpolation='nearest', cmap="gray")
    
    #with heatmap (cooler)
    plt.imshow(image_cropped, interpolation='nearest')
    plt.show()
    sleep(0.005)
    plt.close()
    clear_output(wait=True)
    

    
    
    
crop_square_of_image(0, 0, 50, "69000")



for row in range(127-50):
    if(row % 5 != 0):
        continue
    for col in range(127-50):
        if(col % 5 != 0):
            continue
        crop_square_of_image(col, row, 50, "69000")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-4cbde5032929> in <module>
#      50         if(col % 5 != 0):
#      51             continue
# ---> 52         crop_square_of_image(col, row, 50, "69000")
#      53
#      54
#
# <ipython-input-4-4cbde5032929> in crop_square_of_image(square_top_left_x, square_top_left_y, side_length, image_name)
#      31     #with heatmap (cooler)
#      32     plt.imshow(image_cropped, interpolation='nearest')
# ---> 33     plt.show()
#      34     sleep(0.005)
#      35     plt.close()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
# ...

# %%
import sys

def on_press(event):
    print('press', event.key)
    sys.stdout.flush()
    if event.key == '\x1b[A':
        print("Arrow")
    else:
        print("not arrow")

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt


def on_press(event):
    print('press', event.key)
    sys.stdout.flush()
    if event.key == 'x':
        visible = xl.get_visible()
        xl.set_visible(not visible)
        fig.canvas.draw()


# Fixing random state for reproducibility
np.random.seed(19680801)

fig, ax = plt.subplots()

fig.canvas.mpl_connect('key_press_event', on_press)

ax.plot(np.random.rand(12), np.random.rand(12), 'go')
xl = ax.set_xlabel('easy come, easy go')
ax.set_title('Press a key')
plt.show()

# %%
import ipywidgets as widgets

t = widgets.Text(
    value='Hello World',
    placeholder='Type something',
    description='String:',
    disabled=False
)

def on_enter():
    print('enter key pressed')

t.on_submit(on_enter)

# %%
def on_submit_func(sender):
    print("enter")
    
tagInput = widgets.Text()
tagInput.observe(handle_process_text_submit,names='value')
tagInput.on_submit(on_submit_func)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-533c0afe684e> in <module>
#       3
#       4 tagInput = widgets.Text()
# ----> 5 tagInput.observe(handle_process_text_submit,names='value')
#       6 tagInput.on_submit(on_submit_func)
#
# NameError: name 'handle_process_text_submit' is not defined

# %%
img = mpimg.imread(base_path + image_name + ".png")

imgplot = 0

recreate = False

counter = 0

base_number = 69000


button = widgets.Button(description='Stretch Square Right')
out = widgets.Output()
def on_button_clicked(_):

    global img
    global imgplot
    global counter
    global base_number
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        clear_output()
        print('Something happens!')
        clear_output(wait=True)
        img = img = mpimg.imread(base_path + str(base_number+counter) + ".png")
        imgplot = plt.imshow(img)
        counter = counter + 1
#         print(counter)
        plt.show()

        recreate_button()



base_path = "./69000/"

image_name = "69000"
square_top_left_x = 0
square_top_left_y = 0




#draw the top line
x = [square_top_left_x, square_top_left_x+side_length]
y = [square_top_left_y, square_top_left_y]

plt.plot(x, y, color="white", linewidth=3)

#draw the left line
x = [square_top_left_x, square_top_left_x]
y = [square_top_left_y, square_top_left_y + side_length]

plt.plot(x, y, color="white", linewidth=3)

#draw the right line
x = [square_top_left_x+side_length, square_top_left_x+side_length]
y = [square_top_left_y, square_top_left_y + side_length]

plt.plot(x, y, color="white", linewidth=3)

#draw the bottom line
x = [square_top_left_x, square_top_left_x+side_length]
y = [square_top_left_y+side_length, square_top_left_y+side_length]

plt.plot(x, y, color="white", linewidth=3)


imgplot = plt.imshow(img)
plt.show()



draw_square_on_image(70, 50, 20, "69000")

def recreate_button():
    
    # linking button and function together using a button's method
    button.on_click(on_button_clicked)
    # displaying button and its output together
    widgets.VBox([button,out])

# linking button and function together using a button's method
# button.on_click(on_button_clicked)
# displaying button and its output together
# widgets.VBox([button,out])


# linking button and function together using a button's method
button.on_click(on_button_clicked)
# displaying button and its output together
widgets.VBox([button,out])

# while(True):
#     recreate = False
# #     print("ok")
    
#     while(recreate == False):
#         time.sleep(0.05)
# #         print("hi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-42345509a1a7> in <module>
# ----> 1 img = mpimg.imread(base_path + image_name + ".png")
#       2
#       3 imgplot = 0
#       4
#       5 recreate = False
#
# NameError: name 'image_name' is not defined

# %%
#origin of image is 0, 0 in the top left...
#keep that in mind
def draw_square_on_image(square_top_left_x, square_top_left_y, side_length, image_name):

    
    img = color.rgb2gray(mpimg.imread(base_path + image_name + ".png"))
    
    x_dimens = np.shape(img)[1]
    
    y_dimens = np.shape(img)[0]
    
    if(square_top_left_x + side_length >= x_dimens or square_top_left_x < 0 or square_top_left_x >= x_dimens):
        print("ERROR OUT OF X BOUNDS")
        return
    if(square_top_left_y + side_length >= y_dimens or square_top_left_y < 0 or square_top_left_y >= y_dimens):
        print("ERROR OUT OF Y BOUNDS")
        return
    
    
    #draw the top line
    x = [square_top_left_x, square_top_left_x+side_length]
    y = [square_top_left_y, square_top_left_y]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    #draw the left line
    x = [square_top_left_x, square_top_left_x]
    y = [square_top_left_y, square_top_left_y + side_length]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    #draw the right line
    x = [square_top_left_x+side_length, square_top_left_x+side_length]
    y = [square_top_left_y, square_top_left_y + side_length]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    #draw the bottom line
    x = [square_top_left_x, square_top_left_x+side_length]
    y = [square_top_left_y+side_length, square_top_left_y+side_length]
    
    plt.plot(x, y, color="white", linewidth=3)
    
    
    imgplot = plt.imshow(img, cmap = "gray")
    plt.show()

# %%
#this is for changing which image is shown
#TODO (convert image to grayscale here and below before adding to good data.....)

img = color.rgb2gray(mpimg.imread(base_path + str(68999) + ".png"))

imgplot = 0

recreate = False

counter = 0

#need one dummy image (real image starts at 69000)
base_number = 68999

TL_x = 0

TL_y = 0


change_image_button = widgets.Button(description='Change Image')
right = widgets.Button(description='Move Right')
down = widgets.Button(description='Move Down')
up = widgets.Button(description='Move Up')
left = widgets.Button(description='Move Left')
add_good = widgets.Button(description='Add Good Data')
add_bad = widgets.Button(description='Add Bad Data')
out = widgets.Output()
def change_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)
        
        
        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))
#         imgplot = plt.imshow(img)
        counter = counter + 1
        img  = color.rgb2gray(mpimg.imread(base_path + str(base_number+counter) + ".png"))
#         print(counter)
#         plt.show()

        recreate_buttons()
        
        
def move_square_right_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_x = TL_x + 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        

def move_square_down_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_y = TL_y + 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)
        
        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        
def move_square_up_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_y = TL_y - 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        
def move_square_left_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_x = TL_x - 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()

good_data = []
        
def add_good_square_to_good_data(dummy):

    global img

    image_cropped = img[TL_y:TL_y+20, TL_x:TL_x+20].flatten()
    
    image_cropped = np.concatenate((image_cropped, [1]), axis = 0)

    good_data.append(image_cropped)
    
def add_bad_square_to_good_data(dummy):

    global img

    image_cropped = img[TL_y:TL_y+20, TL_x:TL_x+20].flatten()
    
    image_cropped = np.concatenate((image_cropped, [0]), axis = 0)

    good_data.append(image_cropped)
    
    
def recreate_buttons():
    # linking button and function together using a button's method
    change_image_button.on_click(change_image)
    # linking button and function together using a button's method
    right.on_click(move_square_right_image)
    down.on_click(move_square_down_image)
    up.on_click(move_square_up_image)
    left.on_click(move_square_left_image)
    add_good.on_click(add_good_square_to_good_data)
    add_bad.on_click(add_bad_square_to_good_data)
    # displaying button and its output together
    widgets.VBox([change_image_button,right,down,up,left,add_good,add_bad,out])
    

# linking button and function together using a button's method
change_image_button.on_click(change_image)
# linking button and function together using a button's method
right.on_click(move_square_right_image)
down.on_click(move_square_down_image)
up.on_click(move_square_up_image)
left.on_click(move_square_left_image)
add_good.on_click(add_good_square_to_good_data)
add_bad.on_click(add_bad_square_to_good_data)
# displaying button and its output together
widgets.VBox([change_image_button,right,down,up,left,add_good,add_bad,out])

# %%
# print(len(good_data))
for crop in good_data:
    plt.imshow(crop, interpolation='nearest', cmap = "gray")
    plt.show()
    sleep(1)
    plt.close()
    clear_output(wait=True)

# plt.imshow(good_data[2], interpolation='nearest')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-913cde667b60> in <module>
#       1 # print(len(good_data))
#       2 for crop in good_data:
# ----> 3     plt.imshow(crop, interpolation='nearest', cmap = "gray")
#       4     plt.show()
#       5     sleep(1)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
print(type(good_data[0]))
print(good_data[1])
# Out:
# <class 'numpy.ndarray'>
# [0.05763922 0.09266549 0.1402749  0.05961137 0.03693804 0.24443021
#  0.47537646 0.58820117 0.69076514 0.72157216 0.74173063 0.73972863
#  0.73772669 0.74219882 0.73462355 0.70491767 0.65981609 0.61054003
#  0.56545335 0.50191253 0.06184353 0.08453961 0.12038431 0.06241686
#  0.03693804 0.28892866 0.53471297 0.6075263  0.67447567 0.70893651
#  0.72515845 0.73044908 0.73490632 0.73992902 0.73318708 0.72197294
#  0.71720314 0.70542359 0.67742199 0.64216548 0.06688118 0.06830274
#  0.10077647 0.06158353 0.04870275 0.34688115 0.55795962 0.60388744
#  0.66576159 0.68592    0.70159137 0.72091645 0.73602235 0.74356782
#  0.74748945 0.74466896 0.73737645 0.72841722 0.72559685 0.7104612
#  0.06688118 0.06521451 0.08872902 0.05737922 0.0772549  0.399811
#  0.56076509 0.58820117 0.63969451 0.66180235 0.6839478  0.70971721
#  0.72986078 0.74386549 0.7601251  0.76095843 0.75870353 0.75421643
#  0.74355292 0.74465406 0.06659843 0.06436627 0.09431726 0.06380078
# ...

# %%
#load the good data back in don't start from scratch
np.save('verygooddata.npy', good_data)
# my_data = np.load('testnp.npy')

# %%
for crop in my_data:
    plt.imshow(crop, interpolation='nearest')
    plt.show()
    sleep(1)
    plt.close()
    clear_output(wait=True)

# %%
print(np.shape(good_data[0]))

# %%
print(good_data[0])
# Out:
# [[0.05763922 0.09266549 0.1402749  0.05961137 0.03693804 0.24443021
#   0.47537646 0.58820117 0.69076514 0.72157216 0.74173063 0.7397286
#   0.7377267  0.7421988  0.73462355 0.70491767 0.6598161  0.61054003
#   0.56545335 0.50191253]
#  [0.06184353 0.08453961 0.12038431 0.06241686 0.03693804 0.28892866
#   0.534713   0.6075263  0.67447567 0.7089365  0.72515845 0.7304491
#   0.7349063  0.739929   0.7331871  0.72197294 0.71720314 0.7054236
#   0.677422   0.6421655 ]
#  [0.06688118 0.06830274 0.10077647 0.06158353 0.04870275 0.34688115
#   0.5579596  0.60388744 0.6657616  0.68592    0.7015914  0.72091645
#   0.73602235 0.7435678  0.74748945 0.74466896 0.73737645 0.7284172
#   0.72559685 0.7104612 ]
#  [0.06688118 0.06521451 0.08872902 0.05737922 0.0772549  0.399811
#   0.5607651  0.58820117 0.6396945  0.66180235 0.6839478  0.7097172
#   0.7298608  0.7438655  0.7601251  0.76095843 0.75870353 0.75421643
#   0.7435529  0.74465406]
# ...

# %%
# print(good_data[0].flatten())

for i in range(len(good_data)):
    good_data[i] = good_data[i].flatten()
    
print(good_data[0])

print(len(good_data[0]))
# Out:
# [0.05794471 0.28584826 0.5646867  0.59295607 0.56944156 0.49220157
#  0.4731443  0.5255086  0.60000354 0.65407217 0.7181863  0.7711388
#  0.78205526 0.7769651  0.77526075 0.78308904 0.7934698  0.8007623
#  0.8013129  0.81167877 0.07081059 0.3751506  0.58738273 0.48464116
#  0.36901882 0.37570825 0.4109647  0.43168864 0.45355135 0.5218698
#  0.5845702  0.6621533  0.74283963 0.7753133  0.7865125  0.7861623
#  0.7909172  0.794571   0.80411845 0.8142165  0.11561451 0.44096118
#  0.4731741  0.35475412 0.4471149  0.5607949  0.5580122  0.4384157
#  0.38576862 0.41993177 0.45719802 0.4829447  0.57364666 0.6898573
#  0.7840125  0.7893031  0.77997094 0.7878141  0.7945561  0.80101526
#  0.15538079 0.43117568 0.41351727 0.5095247  0.6793059  0.7356067
#  0.7213043  0.62714905 0.5369381  0.46358195 0.44821608 0.41968668
#  0.44378942 0.49920434 0.6161659  0.7564941  0.7858796  0.7805066
#  0.7807894  0.79061955 0.19179098 0.44013488 0.50423414 0.67955095
# ...

# %%
import pandas as pd 
import numpy as np 
 
dataframe = pd.DataFrame(good_data) 
dataframe.to_csv(r"./eyeball_dataset.csv")

# %%
final_data = np.load('verygooddata.npy')
# print(np.shape(my_data))

# my_data_copy = np.delete(my_data, 400, 1)

# C = []

# for row in my_data:
#     C.append(np.reshape(row, (-1, 20)))

# print(np.shape(C))


# for crop in C:
#     plt.imshow(crop, interpolation='nearest', cmap = "gray")
#     plt.show()
#     sleep(1)
#     plt.close()
#     clear_output(wait=True)

final_data = C


print(np.shape(final_data))
# Out:
# (70, 20, 20)

# %%
#this is for changing which image is shown
#TODO (convert image to grayscale here and below before adding to good data.....)


# np.save('verygooddata.npy', good_data)
# np.save('verygooddata.npy', good_data)
# my_data = np.load('verygooddata.npy')

final_data = []

img = color.rgb2gray(mpimg.imread(base_path + str(68999) + ".png"))

imgplot = 0

recreate = False

counter = 0

#need one dummy image (real image starts at 69000)
base_number = 68999

TL_x = 0

TL_y = 0


change_image_button = widgets.Button(description='Change Image')
right = widgets.Button(description='Move Right')
down = widgets.Button(description='Move Down')
up = widgets.Button(description='Move Up')
left = widgets.Button(description='Move Left')
add_good = widgets.Button(description='Add Good Data')
add_bad = widgets.Button(description='Add Bad Data')
out = widgets.Output()
def change_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)
        
        
        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))
#         imgplot = plt.imshow(img)
        counter = counter + 1
        img  = color.rgb2gray(mpimg.imread(base_path + str(base_number+counter) + ".png"))
#         print(counter)
#         plt.show()

        recreate_buttons()
        
        
def move_square_right_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_x = TL_x + 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        

def move_square_down_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_y = TL_y + 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)
        
        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        
def move_square_up_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_y = TL_y - 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        
def move_square_left_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_x = TL_x - 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()


        
def add_good_square_to_good_data(dummy):

    global img
    global final_data

    image_cropped = img[TL_y:TL_y+20, TL_x:TL_x+20].flatten()
    
    image_cropped = np.concatenate((image_cropped, [1]), axis = 0)

    final_data.append(image_cropped)
    
def add_bad_square_to_good_data(dummy):

    global img
    global final_data

    image_cropped = img[TL_y:TL_y+20, TL_x:TL_x+20].flatten()
    
    image_cropped = np.concatenate((image_cropped, [0]), axis = 0)

    final_data.append(image_cropped)
    
    
def recreate_buttons():
    # linking button and function together using a button's method
    change_image_button.on_click(change_image)
    # linking button and function together using a button's method
    right.on_click(move_square_right_image)
    down.on_click(move_square_down_image)
    up.on_click(move_square_up_image)
    left.on_click(move_square_left_image)
    add_good.on_click(add_good_square_to_good_data)
    add_bad.on_click(add_bad_square_to_good_data)
    # displaying button and its output together
    widgets.VBox([change_image_button,right,down,up,left,add_good,add_bad,out])
    

# linking button and function together using a button's method
change_image_button.on_click(change_image)
# linking button and function together using a button's method
right.on_click(move_square_right_image)
down.on_click(move_square_down_image)
up.on_click(move_square_up_image)
left.on_click(move_square_left_image)
add_good.on_click(add_good_square_to_good_data)
add_bad.on_click(add_bad_square_to_good_data)
# displaying button and its output together
widgets.VBox([change_image_button,right,down,up,left,add_good,add_bad,out])

# %%
#reshape and print images
my_data = np.load('my_best_data_yet.npy')
# print(np.shape(my_data))

# my_data = np.delete(my_data, 400, 1)

print(np.shape(my_data))

# np.save('my_best_data_yet.npy', final_data)

final_data_copy = np.delete(np.copy(my_data), 400, 1)

C = []

for row in final_data_copy:
    C.append(np.reshape(row, (-1, 20)))

print(np.shape(C))



for crop in C:
    plt.imshow(crop, interpolation='nearest')
    plt.show()
    sleep(0.5)
    plt.close()
    clear_output(wait=True)

# %%
print(np.shape(final_data))
# Out:
# (141, 401)

# %%
#loads data from numpy file
final_data = np.load('my_best_data_yet.npy').tolist()
print(np.shape(final_data))
# Out:
# (141, 401)

# %%
#this is for changing which image is shown
#TODO (convert image to grayscale here and below before adding to good data.....)


# np.save('verygooddata.npy', good_data)
# np.save('verygooddata.npy', good_data)
# my_data = np.load('verygooddata.npy')

final_data = []

img = color.rgb2gray(mpimg.imread(base_path + str(68999) + ".png"))

imgplot = 0

recreate = False

counter = 0

#need one dummy image (real image starts at 69000)
base_number = 68999

TL_x = 0

TL_y = 0


change_image_button = widgets.Button(description='Change Image')
right = widgets.Button(description='Move Right')
down = widgets.Button(description='Move Down')
up = widgets.Button(description='Move Up')
left = widgets.Button(description='Move Left')
add_good = widgets.Button(description='Add Good Data')
add_bad = widgets.Button(description='Add Bad Data')
out = widgets.Output()
def change_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)
        
        
        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))
#         imgplot = plt.imshow(img)
        counter = counter + 1
        img  = color.rgb2gray(mpimg.imread(base_path + str(base_number+counter) + ".png"))
#         print(counter)
#         plt.show()

        recreate_buttons()
        
        
def move_square_right_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_x = TL_x + 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        

def move_square_down_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_y = TL_y + 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)
        
        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        
def move_square_up_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_y = TL_y - 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()
        
def move_square_left_image(_):

    global img
    global imgplot
    global counter
    global base_number
    global TL_x
    global TL_y
    
    
    
    # "linking function with output"
    with out:
        # what happens when we press the button
        TL_x = TL_x - 5
#         clear_output()
        print('Something happens!')
        clear_output(wait=True)

        draw_square_on_image(TL_x, TL_y, 20, str(base_number+counter))


        recreate_buttons()


        
def add_good_square_to_good_data(dummy):

    global img
    global final_data

    image_cropped = img[TL_y:TL_y+20, TL_x:TL_x+20].flatten()
    
    image_cropped = np.concatenate((image_cropped, [1]), axis = 0)

    final_data.append(image_cropped)
    
def add_bad_square_to_good_data(dummy):

    global img
    global final_data

    image_cropped = img[TL_y:TL_y+20, TL_x:TL_x+20].flatten()
    
    image_cropped = np.concatenate((image_cropped, [0]), axis = 0)

    final_data.append(image_cropped)
    
    
def recreate_buttons():
    # linking button and function together using a button's method
    change_image_button.on_click(change_image)
    # linking button and function together using a button's method
    right.on_click(move_square_right_image)
    down.on_click(move_square_down_image)
    up.on_click(move_square_up_image)
    left.on_click(move_square_left_image)
    add_good.on_click(add_good_square_to_good_data)
    add_bad.on_click(add_bad_square_to_good_data)
    # displaying button and its output together
    widgets.VBox([change_image_button,right,down,up,left,add_good,add_bad,out])
    

# linking button and function together using a button's method
change_image_button.on_click(change_image)
# linking button and function together using a button's method
right.on_click(move_square_right_image)
down.on_click(move_square_down_image)
up.on_click(move_square_up_image)
left.on_click(move_square_left_image)
add_good.on_click(add_good_square_to_good_data)
add_bad.on_click(add_bad_square_to_good_data)
# displaying button and its output together
widgets.VBox([change_image_button,right,down,up,left,add_good,add_bad,out])

# %%
print(np.shape(final_data))
# Out:
# (143, 401)

# %%
import pandas as pd 
import numpy as np 
 
dataframe = pd.DataFrame(final_data) 
dataframe.to_csv(r"./eyeball_dataset2.csv")
